# %% [markdown]
# <a href="https://colab.research.google.com/github/adjisaefularif/Pemrograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama_lengkap ="adji saeful arif"
nim ="4232511060"
umur =22
jurusan ="Elektro"
prodi = "TRPE"
semester =3
matakuliah ="PEMROGRAMAN DASAR"
alamat ="TEMBESI"
hobi ="membaca"
status_lulus =False


print(nama_lengkap)
print(nim)
print(umur)
print(jurusan)
print(prodi)
print(semester)
print(matakuliah)
print(alamat)
print(hobi)
print(status_lulus)
# Out:
# adji saeful arif
# 4232511060
# 22
# Elektro
# TRPE
# 3
# PEMROGRAMAN DASAR
# TEMBESI
# membaca
# False

# %% [markdown]
# # New Section
