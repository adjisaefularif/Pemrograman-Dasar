# %% [markdown]
# <a href="https://colab.research.google.com/github/adjisaefularif/Pemrograman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama ="adji saeful arif"
umur =22
jurusan ="Elektro"
prodi = "TRPE"
semester =3
matakuliah ="PEMROGRAMAN DASAR"
status_lulus =True


print(nama)
print(umur)
print(jurusan)
print(semester)
print(matakuliah)
print(status_lulus)
# Out:
# adji saeful arif
# 22
# Elektro
# 3
# PEMROGRAMAN DASAR
# True

# %% [markdown]
# # New Section
